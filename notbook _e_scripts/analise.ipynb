# %% [markdown]
#  # <font color="skyblue"> skyblue
#  ## relatório de andamento de software

# %%
import scripts as ss
#no intuito de não retirar a atenção da analise na busca entender os scripts utilizados foi decidido que os scripts deveriam ficar em um arquivo 
#diferente que esta disponibilizado e comentado para melhor entendimento, esta nesse mesmo repositorio com o nome `visualizacao.py`.

# %% [markdown]
# ### <font color="skyblue"> observação dos dados

# %% [markdown]
# Ao iniciar a nossa análise, o primeiro passo foi buscar os dados mais recentes dos principais indicadores e compreender o andamento do software através das horas trabalhadas, tarefas concluídas e bugs.
#
# * O primeiro problema encontrado foi observar que a equipe está com uma carga horária superior a 40 horas semanais, o que, além de causar danos aos colaboradores, pode acarretar diversos problemas trabalhistas.

# %%
print(f' horas trabalhadas na ultima semana {int(ss.respostas["Total de Horas Trabalhadas"])}h')
# Out:
#  horas trabalhadas na ultima semana 56h

# %% [markdown]
# * Após isso, o segundo passo foi supervisionar a qualidade do software que está sendo construído através da resolução de bugs nesta semana. O segundo problema é que, como visto abaixo, a média de bugs corrigidos na semana foi inferior ao número de bugs que ainda estão a corrigir, representando uma ineficiência na resolução dos problemas no código.

# %%
print(f' bugs corrigidos na semanas: {int(ss.respostas["total de Bugs Corrigidos"])} \n bugs pendentes: {int(ss.respostas["bugs a serem resolvidos"])}')
# Out:
#  bugs corrigidos na semanas: 18
#  bugs pendentes: 19

# %% [markdown]
# * Por fim, busquei observar o andamento da produtividade diária, que é o número de tarefas concluídas por hora. Como mostrado em azul, o sábado possui a maior produtividade, sendo bastante diferente dos demais dias. No sábado em questão, os colaboradores trabalharam cerca de 6 horas, enquanto na sexta-feira o número de horas foi de 10 horas, o que pode indicar que as grandes jornadas estão atrapalhando a produtividade dos colaboradores

# %%
ss.resposta_7()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# abaixo estão as informações comentadas acima é outras que foram solicitadas pelo contratante.

# %%
ss.respostas
# Out:
# Total de Horas Trabalhadas            56.0
# Média Diária de Horas Trabalhadas      9.3
# total de Bugs Corrigidos              18.0
# Média Diária de Bugs Corrigidos        3.0
# Total de Tarefas Concluídas           33.0
# Média Diária de Tarefas Concluídas     5.5
# bugs a serem resolvidos               19.0
# dtype: float64

# %% [markdown]
# ### <font color="#B22222"> **uma analise maior**

# %% [markdown]
# **A análise acima foi construída com base em uma gama muito pequena de dados, o que levou à decisão de ampliar a abrangência das informações. Com o objetivo de encontrar respostas para algumas perguntas, decidiu-se observar uma amostra maior. Isso inclui buscar entender o motivo por trás das muitas horas extras e também a razão da ineficiência na resolução de bugs. Por conta disso, essa análise abaixo contém os dados das quatro últimas semanas:**

# %% [markdown]
# Observamos que na primeira semana a equipe possuía um número de quatro colaboradores, e na última semana, apenas dois, ou seja, 50% da equipe foi cortada. Ao longo das próximas visualizações, mostrarei como esses cortes afetaram o rendimento da equipe e os danos que isso pode gerar à sua companhia.

# %%
ss.queda_pr()

# %% [markdown]
# #### <font color="#B22222">  **tarefas concluidas**

# %% [markdown]
# Como mostrado abaixo, na primeira semana o número de tarefas concluídas caiu a um pouco mais da metade em comparação com antes, e a linha descendente no gráfico demonstra claramente o vínculo entre a saída dos colaboradores e a perda de produtividade.

# %%
ss.relatorio_extra()

# %% [markdown]
# #### <font color="#B22222"> **correção de bugs**

# %% [markdown]
# A partir da terceira semana, a equipe deixou de dar conta das resoluções dos bugs, fazendo com que o número de bugs não corrigidos saísse de zero na segunda semana para mais de cinquenta por cento na quarta semana

# %%
ss.horas_trabalhadas()

# %% [markdown]
# #### <font color="#B22222"> **carga horária**

# %% [markdown]
# A carga horária a partir da terceira semana teve um aumento, o que pode se tornar um problema jurídico para a empresa.

# %% [markdown]
# ### <font color="#B22222">**recomendação**

# %% [markdown]
# Os dados acima são extremamente alarmantes. A queda de produtividade e a quantidade crescente de bugs não resolvidos podem atrasar a entrega do projeto e impedir a aquisição de novos clientes. Além disso, a carga horária atual da equipe, se levada à justiça, pode custar muito caro à empresa. Levando tudo isso em conta, recomenda-se, preferencialmente, a contratação de mais um funcionário e estender o prazo de entrega do software.
#
# Contratar duas pessoas representa um desafio maior em relação ao treinamento dos novos colaboradores. Enquanto a entrega do projeto por somente dois colaboradores seria praticamente inviável na data desejada ou até mesmo em uma data próxima.
#
# Dessa forma, é imprescindível considerar essas opções para garantir a qualidade do projeto, evitar problemas jurídicos e possibilitar a realização do trabalho dentro de prazos adequados.
